# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
ser= pd.Series(np.random.random(5),name="Column 1")

# %%
ser
# Out:
# 0    0.626287
# 1    0.227971
# 2    0.334486
# 3    0.042476
# 4    0.626296
# Name: Column 1, dtype: float64

# %%
ser[2]
# Out:
# 0.3344859712433885

# %%
from pandas_datareader import data as pdr
yf.pdr_override()

# %%
PG = pdr.get_data_yahoo("PG", start = "2015-1-1", end = "2022-12-3")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
PG
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-02   90.839996   91.000000   89.919998   90.440002   70.860840
# 2015-01-05   90.230003   91.000000   89.849998   90.010002   70.523956
# 2015-01-06   90.309998   90.559998   89.260002   89.599998   70.202682
# 2015-01-07   89.940002   90.370003   89.559998   90.070000   70.570953
# 2015-01-08   90.480003   91.230003   90.129997   91.099998   71.377968
# ...                ...         ...         ...         ...         ...
# 2022-11-28  146.389999  147.339996  146.139999  146.600006  144.779373
# 2022-11-29  145.750000  146.059998  144.529999  145.479996  143.673279
# 2022-11-30  145.649994  149.160004  145.130005  149.160004  147.307587
# 2022-12-01  149.529999  150.360001  148.570007  149.250000  147.396469
# 2022-12-02  148.470001  150.770004  148.080002  150.610001  148.739578
#
#               Volume
# Date
# 2015-01-02   7251400
# 2015-01-05   8626100
# 2015-01-06   7791200
# ...

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1995 entries, 2015-01-02 to 2022-12-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1995 non-null   float64
#  1   High       1995 non-null   float64
#  2   Low        1995 non-null   float64
#  3   Close      1995 non-null   float64
#  4   Adj Close  1995 non-null   float64
#  5   Volume     1995 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 109.1 KB

# %%
PG.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-01-02  90.839996  91.000000  89.919998  90.440002  70.860840  7251400
# 2015-01-05  90.230003  91.000000  89.849998  90.010002  70.523956  8626100
# 2015-01-06  90.309998  90.559998  89.260002  89.599998  70.202682  7791200
# 2015-01-07  89.940002  90.370003  89.559998  90.070000  70.570953  5986600
# 2015-01-08  90.480003  91.230003  90.129997  91.099998  71.377968  6823300

# %% [markdown]
# PG.head() first five, PG.tail() last five

# %%
PG.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-28  146.389999  147.339996  146.139999  146.600006  144.779373
# 2022-11-29  145.750000  146.059998  144.529999  145.479996  143.673279
# 2022-11-30  145.649994  149.160004  145.130005  149.160004  147.307587
# 2022-12-01  149.529999  150.360001  148.570007  149.250000  147.396469
# 2022-12-02  148.470001  150.770004  148.080002  150.610001  148.739578
#
#               Volume
# Date
# 2022-11-28   6628200
# 2022-11-29   5634200
# 2022-11-30  12396800
# 2022-12-01   6927400
# 2022-12-02   4938300

# %%
PG.head(20)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  90.839996  91.000000  89.919998  90.440002  70.860840   7251400
# 2015-01-05  90.230003  91.000000  89.849998  90.010002  70.523956   8626100
# 2015-01-06  90.309998  90.559998  89.260002  89.599998  70.202682   7791200
# 2015-01-07  89.940002  90.370003  89.559998  90.070000  70.570953   5986600
# 2015-01-08  90.480003  91.230003  90.129997  91.099998  71.377968   6823300
# 2015-01-09  91.180000  91.180000  90.120003  90.250000  70.711990   4872800
# 2015-01-12  90.480003  90.620003  89.510002  89.919998  70.453423   5250900
# 2015-01-13  90.779999  91.500000  89.769997  90.300003  70.751167   6727100
# 2015-01-14  89.730003  90.160004  89.430000  89.989998  70.508263   6418200
# 2015-01-15  90.489998  90.500000  89.339996  89.860001  70.406418   6768200
# 2015-01-16  89.949997  91.339996  89.870003  91.250000  71.495499   8815700
# ...

# %%
PG.tail(20)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-04  133.320007  135.000000  132.520004  134.440002  132.770401
# 2022-11-07  135.350006  137.190002  135.059998  136.500000  134.804810
# 2022-11-08  136.820007  137.520004  135.800003  136.809998  135.110962
# 2022-11-09  136.869995  137.970001  136.339996  136.479996  134.785049
# 2022-11-10  139.460007  141.630005  138.199997  141.179993  139.426682
# 2022-11-11  141.199997  141.630005  139.110001  140.970001  139.219299
# 2022-11-14  140.509995  143.559998  140.259995  140.979996  139.229172
# 2022-11-15  142.089996  143.199997  139.699997  140.490005  138.745255
# 2022-11-16  141.500000  142.910004  140.979996  141.740005  139.979736
# 2022-11-17  141.110001  141.690002  139.860001  140.869995  139.120529
# 2022-11-18  141.919998  142.759995  141.270004  142.570007  140.799423
# 2022-11-21  143.059998  145.190002  142.830002  144.380005  142.586945
# ...
